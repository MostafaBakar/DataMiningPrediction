# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Final_Employees_Data.csv')

# %%
len(dataset)
# Out:
# 298

# %%
dataset.head()
# Out:
#   EducationLevel   Age    Salary  YearsOfExperience  Gender           JobTitle
# 0     Bachelor's  32.0   90000.0                5.0    Male         Accountant
# 1       Master's  28.0   65000.0                3.0  Female   Business Analyst
# 2            PhD  45.0       NaN               15.0    Male     Data Scientist
# 3     Bachelor's  36.0   60000.0                NaN  Female  Software Engineer
# 4       Master's  52.0  200000.0               20.0    Male  Software Engineer

# %%
dataset.describe()
# Out:
#               Age         Salary  YearsOfExperience
# count  295.000000     290.000000         294.000000
# mean    37.281356   98587.413793          10.127551
# std      7.283297   48168.944918           6.670184
# min     23.000000     350.000000           0.000000
# 25%     31.000000   55000.000000           4.000000
# 50%     36.000000   95000.000000           9.000000
# 75%     43.500000  130000.000000          15.000000
# max     53.000000  250000.000000          25.000000

# %%
dataset.dtypes
# Out:
# EducationLevel        object
# Age                  float64
# Salary               float64
# YearsOfExperience    float64
# Gender                object
# JobTitle              object
# dtype: object

# %%
dataset.isnull()
# Out:
#      EducationLevel    Age  Salary  YearsOfExperience  Gender  JobTitle
# 0             False  False   False              False   False     False
# 1             False  False   False              False   False     False
# 2             False  False    True              False   False     False
# 3             False  False   False               True   False     False
# 4             False  False   False              False   False     False
# ..              ...    ...     ...                ...     ...       ...
# 293           False  False   False              False   False     False
# 294           False  False   False              False   False     False
# 295           False  False   False              False   False     False
# 296           False  False   False              False   False     False
# 297           False  False   False              False   False     False
#
# [298 rows x 6 columns]

# %%
dataset.isnull().any()
# Out:
# EducationLevel       False
# Age                   True
# Salary                True
# YearsOfExperience     True
# Gender               False
# JobTitle             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# EducationLevel       0
# Age                  3
# Salary               8
# YearsOfExperience    4
# Gender               0
# JobTitle             0
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# 15

# %%
dataEncoding = dataset.replace({
    'Gender':{'Male':0,'Female':1},
    'EducationLevel':{'Bachelor\'s':0,'Master\'s':1,'PhD':2}}
)
dataEncoding
# Out:
#      EducationLevel   Age    Salary  YearsOfExperience  Gender  \
# 0                 0  32.0   90000.0                5.0       0
# 1                 1  28.0   65000.0                3.0       1
# 2                 2  45.0       NaN               15.0       0
# 3                 0  36.0   60000.0                NaN       1
# 4                 1  52.0  200000.0               20.0       0
# ..              ...   ...       ...                ...     ...
# 293               0  33.0   60000.0                4.0       0
# 294               0  40.0  130000.0               12.0       1
# 295               2  44.0  160000.0               16.0       0
# 296               0  30.0   40000.0                2.0       1
# 297               0  37.0  100000.0                9.0       0
#
#               JobTitle
# 0           Accountant
# 1     Business Analyst
# 2       Data Scientist
# 3    Software Engineer
# 4    Software Engineer
# ..                 ...
# 293  Software Engineer
# 294     Data Scientist
# 295  Software Engineer
# 296  Marketing Manager
# 297     Data Scientist
#
# [298 rows x 6 columns]

# %%
dataEncoding2 = pd.get_dummies(dataEncoding)
dataEncoding2.head()
# Out:
#    EducationLevel   Age    Salary  YearsOfExperience  Gender  \
# 0               0  32.0   90000.0                5.0       0
# 1               1  28.0   65000.0                3.0       1
# 2               2  45.0       NaN               15.0       0
# 3               0  36.0   60000.0                NaN       1
# 4               1  52.0  200000.0               20.0       0
#
#    JobTitle_Accountant  JobTitle_Business Analyst  JobTitle_Data Scientist  \
# 0                 True                      False                    False
# 1                False                       True                    False
# 2                False                      False                     True
# 3                False                      False                    False
# 4                False                      False                    False
#
#    JobTitle_Marketing Manager  JobTitle_Software Engineer
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                        True
# 4                       False                        True

# %%
from sklearn.impute import SimpleImputer
X = dataset.iloc[:,:-1].values
X[:, 1:4]
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, 1:4])
X[:, 1:4] = imputer.transform(X[:, 1:4])
X
# Out:
# array([["Bachelor's", 32.0, 90000.0, 5.0, 'Male'],
#        ["Master's", 28.0, 65000.0, 3.0, 'Female'],
#        ['PhD', 45.0, 98587.41379310345, 15.0, 'Male'],
#        ...,
#        ['PhD', 44.0, 160000.0, 16.0, 'Male'],
#        ["Bachelor's", 30.0, 40000.0, 2.0, 'Female'],
#        ["Bachelor's", 37.0, 100000.0, 9.0, 'Male']], dtype=object)

# %%
# Splitting the dataset into the training set and test set
from sklearn.model_selection import train_test_split
Y=dataset.iloc[:,-1].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)
print(X_train)
print(X_test)
print(y_train)
# print(y_test) 
print(y_test)
# Out:
# [['PhD' 44.0 145000.0 15.0 'Female']
#  ["Bachelor's" 36.0 60000.0 7.0 'Male']
#  ["Bachelor's" 29.0 35000.0 1.5 'Male']
#  ...
#  ['PhD' 45.0 98587.41379310345 16.0 'Male']
#  ["Bachelor's" 37.0 100000.0 9.0 'Female']
#  ["Master's" 42.0 115000.0 14.0 'Male']]
# [["Bachelor's" 36.0 60000.0 7.0 'Male']
#  ["Bachelor's" 32.0 45000.0 3.0 'Male']
#  ["Master's" 33.0 85000.0 7.0 'Male']
#  ["Bachelor's" 35.0 80000.0 7.0 'Male']
#  ["Bachelor's" 34.0 70000.0 6.0 'Female']
#  ["Bachelor's" 35.0 95000.0 9.0 'Male']
#  ["Bachelor's" 38.0 120000.0 9.0 'Female']
#  ["Bachelor's" 40.0 80000.0 12.0 'Female']
#  ["Bachelor's" 24.0 40000.0 1.0 'Male']
#  ["Bachelor's" 33.0 50000.0 5.0 'Female']
#  ["Master's" 42.0 110000.0 15.0 'Female']
#  ['PhD' 48.0 170000.0 20.0 'Male']
#  ["Bachelor's" 48.0 140000.0 18.0 'Female']
#  ['PhD' 50.0 180000.0 22.0 'Female']
#  ["Master's" 41.0 100000.0 14.0 'Female']
#  ["Bachelor's" 34.0 100000.0 9.0 'Male']
#  ['PhD' 44.0 160000.0 16.0 'Male']
#  ["Bachelor's" 45.0 110000.0 18.0 'Male']
#  ["Master's" 47.0 180000.0 20.0 'Female']
#  ["Bachelor's" 28.0 40000.0 2.0 'Male']
#  ['PhD' 44.0 220000.0 16.0 'Male']
#  ["Bachelor's" 35.0 65000.0 6.0 'Male']
#  ["Master's" 43.0 120000.0 14.0 'Female']
#  ["Bachelor's" 25.0 35000.0 0.0 'Female']
#  ["Master's" 49.0 180000.0 21.0 'Female']
#  ['PhD' 46.0 160000.0 18.0 'Male']
#  ["Bachelor's" 37.0 100000.0 9.0 'Male']
#  ["Bachelor's" 35.0 90000.0 7.0 'Male']
#  ["Master's" 48.0 175000.0 21.0 'Male']
#  ["Bachelor's" 38.0 80000.0 10.0 'Female']
#  ["Bachelor's" 29.0 40000.0 1.5 'Male']
#  ['PhD' 46.0 150000.0 18.0 'Male']
#  ["Master's" 34.0 95000.0 10.0 'Female']
#  ['PhD' 36.0 120000.0 11.0 'Male']
#  ["Master's" 26.0 45000.0 1.5 'Female']
#  ["Bachelor's" 43.0 140000.0 16.0 'Male']
#  ["Master's" 34.0 100000.0 6.0 'Female']
#  ["Bachelor's" 31.0 60000.0 4.0 'Male']
#  ["Master's" 46.0 135000.0 21.0 'Male']
#  ["Bachelor's" 28.0 35000.0 1.5 'Male']
#  ["Master's" 52.0 200000.0 20.0 'Male']
#  ["Bachelor's" 34.0 95000.0 7.0 'Male']
#  ["Bachelor's" 30.0 40000.0 2.0 'Female']
#  ["Bachelor's" 31.0 50000.0 3.0 'Male']
#  ["Master's" 33.0 115000.0 7.0 'Male']
#  ["Master's" 33.0 90000.0 7.0 'Female']
#  ["Bachelor's" 33.0 65000.0 6.0 'Male']
#  ["Bachelor's" 31.0 50000.0 3.0 'Male']
#  ["Bachelor's" 30.0 55000.0 4.0 'Female']
#  ["Bachelor's" 29.0 40000.0 3.0 'Female']
#  ["Bachelor's" 29.0 40000.0 2.0 'Male']
#  ['PhD' 45.0 150000.0 15.0 'Female']
#  ['PhD' 51.0 185000.0 23.0 'Female']
#  ["Master's" 35.0 105000.0 7.0 'Male']
#  ["Master's" 48.0 170000.0 19.0 'Male']
#  ["Bachelor's" 28.0 40000.0 2.0 'Male']
#  ["Bachelor's" 28.0 40000.0 2.0 'Male']
#  ['PhD' 44.0 160000.0 18.0 'Female']
#  ["Bachelor's" 29.0 98587.41379310345 3.0 'Female']
#  ["Master's" 27.0 45000.0 10.127551020408163 'Female']]
# ['Business Analyst' 'Marketing Manager' 'Marketing Manager'
#  'Software Engineer' 'Accountant' 'Accountant' 'Accountant'
#  'Business Analyst' 'Accountant' 'Data Scientist' 'Marketing Manager'
#  'Software Engineer' 'Business Analyst' 'Accountant' 'Marketing Manager'
#  'Accountant' 'Marketing Manager' 'Business Analyst' 'Data Scientist'
#  'Marketing Manager' 'Marketing Manager' 'Marketing Manager'
#  'Business Analyst' 'Data Scientist' 'Marketing Manager'
#  'Marketing Manager' 'Accountant' 'Marketing Manager' 'Software Engineer'
#  'Data Scientist' 'Accountant' 'Accountant' 'Software Engineer'
#  'Accountant' 'Marketing Manager' 'Accountant' 'Data Scientist'
#  'Business Analyst' 'Software Engineer' 'Accountant' 'Marketing Manager'
#  'Marketing Manager' 'Software Engineer' 'Data Scientist' 'Accountant'
#  'Accountant' 'Marketing Manager' 'Accountant' 'Marketing Manager'
#  'Marketing Manager' 'Marketing Manager' 'Business Analyst' 'Accountant'
#  'Marketing Manager' 'Data Scientist' 'Business Analyst'
#  'Business Analyst' 'Data Scientist' 'Accountant' 'Accountant'
#  'Software Engineer' 'Marketing Manager' 'Marketing Manager'
#  'Business Analyst' 'Data Scientist' 'Accountant' 'Marketing Manager'
#  'Software Engineer' 'Data Scientist' 'Accountant' 'Marketing Manager'
#  'Software Engineer' 'Marketing Manager' 'Accountant' 'Business Analyst'
#  'Accountant' 'Business Analyst' 'Data Scientist' 'Business Analyst'
#  'Software Engineer' 'Marketing Manager' 'Data Scientist' 'Accountant'
#  'Data Scientist' 'Business Analyst' 'Marketing Manager'
#  'Marketing Manager' 'Business Analyst' 'Business Analyst'
#  'Software Engineer' 'Business Analyst' 'Data Scientist' 'Data Scientist'
#  'Marketing Manager' 'Data Scientist' 'Software Engineer'
#  'Business Analyst' 'Marketing Manager' 'Data Scientist' 'Data Scientist'
#  'Data Scientist' 'Marketing Manager' 'Data Scientist' 'Software Engineer'
#  'Software Engineer' 'Marketing Manager' 'Marketing Manager'
#  'Software Engineer' 'Marketing Manager' 'Marketing Manager'
#  'Business Analyst' 'Data Scientist' 'Marketing Manager' 'Data Scientist'
#  'Data Scientist' 'Accountant' 'Business Analyst' 'Accountant'
#  'Business Analyst' 'Marketing Manager' 'Accountant' 'Marketing Manager'
#  'Business Analyst' 'Marketing Manager' 'Accountant' 'Accountant'
#  'Software Engineer' 'Accountant' 'Software Engineer' 'Business Analyst'
#  'Marketing Manager' 'Data Scientist' 'Accountant' 'Marketing Manager'
#  'Business Analyst' 'Business Analyst' 'Accountant' 'Marketing Manager'
#  'Data Scientist' 'Accountant' 'Business Analyst' 'Business Analyst'
#  'Software Engineer' 'Accountant' 'Data Scientist' 'Software Engineer'
#  'Data Scientist' 'Marketing Manager' 'Data Scientist' 'Data Scientist'
#  'Marketing Manager' 'Marketing Manager' 'Business Analyst'
#  'Data Scientist' 'Software Engineer' 'Marketing Manager' 'Accountant'
#  'Software Engineer' 'Accountant' 'Business Analyst' 'Business Analyst'
#  'Data Scientist' 'Accountant' 'Accountant' 'Business Analyst'
#  'Data Scientist' 'Software Engineer' 'Data Scientist' 'Business Analyst'
#  'Accountant' 'Data Scientist' 'Software Engineer' 'Accountant'
#  'Marketing Manager' 'Marketing Manager' 'Accountant' 'Marketing Manager'
#  'Accountant' 'Accountant' 'Data Scientist' 'Business Analyst'
#  'Marketing Manager' 'Software Engineer' 'Accountant' 'Business Analyst'
#  'Business Analyst' 'Business Analyst' 'Software Engineer'
#  'Marketing Manager' 'Marketing Manager' 'Software Engineer'
#  'Marketing Manager' 'Software Engineer' 'Data Scientist'
#  'Marketing Manager' 'Software Engineer' 'Business Analyst' 'Accountant'
#  'Business Analyst' 'Business Analyst' 'Data Scientist' 'Accountant'
#  'Accountant' 'Software Engineer' 'Business Analyst' 'Marketing Manager'
#  'Accountant' 'Marketing Manager' 'Software Engineer' 'Marketing Manager'
#  'Accountant' 'Accountant' 'Accountant' 'Business Analyst'
#  'Business Analyst' 'Accountant' 'Business Analyst' 'Data Scientist'
#  'Data Scientist' 'Data Scientist' 'Business Analyst' 'Marketing Manager'
#  'Business Analyst' 'Accountant' 'Software Engineer' 'Business Analyst'
#  'Software Engineer' 'Accountant' 'Marketing Manager' 'Data Scientist'
#  'Accountant' 'Software Engineer' 'Data Scientist' 'Business Analyst'
#  'Accountant' 'Software Engineer' 'Software Engineer' 'Accountant']
# ['Accountant' 'Software Engineer' 'Accountant' 'Business Analyst'
#  'Marketing Manager' 'Marketing Manager' 'Software Engineer'
#  'Marketing Manager' 'Data Scientist' 'Accountant' 'Data Scientist'
#  'Business Analyst' 'Software Engineer' 'Marketing Manager'
#  'Data Scientist' 'Software Engineer' 'Software Engineer'
#  'Software Engineer' 'Data Scientist' 'Accountant' 'Accountant'
#  'Marketing Manager' 'Accountant' 'Data Scientist' 'Business Analyst'
#  'Accountant' 'Data Scientist' 'Marketing Manager' 'Software Engineer'
#  'Business Analyst' 'Marketing Manager' 'Software Engineer'
#  'Marketing Manager' 'Business Analyst' 'Business Analyst'
#  'Software Engineer' 'Software Engineer' 'Marketing Manager'
#  'Marketing Manager' 'Software Engineer' 'Software Engineer'
#  'Marketing Manager' 'Business Analyst' 'Marketing Manager'
#  'Marketing Manager' 'Data Scientist' 'Marketing Manager' 'Data Scientist'
#  'Business Analyst' 'Accountant' 'Software Engineer' 'Business Analyst'
#  'Software Engineer' 'Business Analyst' 'Business Analyst' 'Accountant'
#  'Software Engineer' 'Data Scientist' 'Business Analyst'
#  'Marketing Manager']
